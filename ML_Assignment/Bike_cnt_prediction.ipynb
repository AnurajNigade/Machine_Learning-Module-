# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
import os

# %%
df = pd.read_csv('day.csv')

# %% [markdown]
# #### Display first 5 rows

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Display last 5 rows

# %%
df.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 725      726  27-12-2019       1   1    12        0        5           1
# 726      727  28-12-2019       1   1    12        0        6           0
# 727      728  29-12-2019       1   1    12        0        0           0
# 728      729  30-12-2019       1   1    12        0        1           1
# 729      730  31-12-2019       1   1    12        0        2           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# ...

# %% [markdown]
# #### If you want to drop column

# %%
df.drop(['yr','mnth','casual'],axis=1)
# Out:
#      instant      dteday  season  holiday  weekday  workingday  weathersit  \
# 0          1  01-01-2018       1        0        1           1           2
# 1          2  02-01-2018       1        0        2           1           2
# 2          3  03-01-2018       1        0        3           1           1
# 3          4  04-01-2018       1        0        4           1           1
# 4          5  05-01-2018       1        0        5           1           1
# ..       ...         ...     ...      ...      ...         ...         ...
# 725      726  27-12-2019       1        0        5           1           2
# 726      727  28-12-2019       1        0        6           0           2
# 727      728  29-12-2019       1        0        0           0           2
# 728      729  30-12-2019       1        0        1           1           1
# 729      730  31-12-2019       1        0        2           1           2
#
#           temp     atemp      hum  windspeed  registered   cnt
# ...

# %% [markdown]
# #### Information about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# #### Checking datatype

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# #### Shape of data

# %%
df.shape
# Out:
# (730, 16)

# %% [markdown]
# ##### Shape of duplicate data value

# %%
df[df.duplicated()].shape
# Out:
# (0, 16)

# %% [markdown]
# #### Count of rows in each column

# %%
df.count()
# Out:
# instant       730
# dteday        730
# season        730
# yr            730
# mnth          730
# holiday       730
# weekday       730
# workingday    730
# weathersit    730
# temp          730
# atemp         730
# hum           730
# windspeed     730
# casual        730
# registered    730
# cnt           730
# dtype: int64

# %% [markdown]
# ### Drop duplicate value

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.count()
# Out:
# instant       730
# dteday        730
# season        730
# yr            730
# mnth          730
# holiday       730
# weekday       730
# workingday    730
# weathersit    730
# temp          730
# atemp         730
# hum           730
# windspeed     730
# casual        730
# registered    730
# cnt           730
# dtype: int64

# %% [markdown]
# There are no duplicate value in dataset

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# There are no null value in dataset
#
# if exist :
# df.dropna(inplace=True)

# %% [markdown]
#  #### To change column name

# %%
df.rename(columns={'yr':'year'})
# Out:
#      instant      dteday  season  year  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1     0     1        0        1           1
# 1          2  02-01-2018       1     0     1        0        2           1
# 2          3  03-01-2018       1     0     1        0        3           1
# 3          4  04-01-2018       1     0     1        0        4           1
# 4          5  05-01-2018       1     0     1        0        5           1
# ..       ...         ...     ...   ...   ...      ...      ...         ...
# 725      726  27-12-2019       1     1    12        0        5           1
# 726      727  28-12-2019       1     1    12        0        6           0
# 727      728  29-12-2019       1     1    12        0        0           0
# 728      729  30-12-2019       1     1    12        0        1           1
# 729      730  31-12-2019       1     1    12        0        2           1
#
# ...

# %% [markdown]
# #### Description of data (mean,count,std)

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df2 = df.drop("dteday",axis=1)
df2
# Out:
#      instant  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0          1       1   0     1        0        1           1           2
# 1          2       1   0     1        0        2           1           2
# 2          3       1   0     1        0        3           1           1
# 3          4       1   0     1        0        4           1           1
# 4          5       1   0     1        0        5           1           1
# ..       ...     ...  ..   ...      ...      ...         ...         ...
# 725      726       1   1    12        0        5           1           2
# 726      727       1   1    12        0        6           0           2
# 727      728       1   1    12        0        0           0           2
# 728      729       1   1    12        0        1           1           1
# 729      730       1   1    12        0        2           1           2
#
#           temp     atemp      hum  windspeed  casual  registered   cnt
# ...

# %% [markdown]
# droping dteday column because for correlation coefficient only numeric data allowed

# %%
import seaborn as sb
plt.figure(figsize=(15,6))
sb.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Looking at above heatmap
#
# column season, year, month, temp have positive correlation with column count of bike.
# column holiday, working day, weather situation have neagtive correlation with count of bike.

# %% [markdown]
# ### Count of bike each month

# %%
import pylab
from pylab import plot,show,legend

# %%
plt.bar(df.mnth,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# Count of rented bikes according to months.

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
plt.bar(df.season,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# Looking at above plot, maximum number of bikes are rented in fall season.

# %%
plt.bar(df.yr,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# In year 2019 rented bikes are more than 2018.

# %%
plt.bar(df.holiday,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# On holidays bikes are rented more.

# %%
plt.bar(df.weekday,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# On sunday number of rented bikes are slightly more than other days.

# %%
plt.bar(df.workingday,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# On working day rented bikes count is less than holidays.

# %%
plt.bar(df.weathersit,df.cnt)
# Out:
# <BarContainer object of 730 artists>

# %% [markdown]
# In Clear weather bike count is more compare to Mist,Light snow or Heavy Rain weather.

# %%
plt.scatter(df.temp,df.cnt)
plt.show()

# %% [markdown]
# Looking at above scatter plot the most rented bike are at temperature between 20 to 30.

# %%
plt.scatter(df.hum,df.cnt)
plt.show()

# %% [markdown]
# The most number of bikes are rented at humidity between 50 to 80.

# %%
plt.scatter(df.windspeed,df.cnt)
plt.show()

# %% [markdown]
# when wind speed is low i.e in between 5 to 15 then count of rented bike is more

# %%
plt.scatter(df.temp,df.cnt,s=df.weekday)
plt.show()

# %% [markdown]
# Above plot shows that relation between how temperature  and weekday affect on rented bike count.

# %% [markdown]
# # Conclusion :  By looking at above relation we can say that  season , weather situation,temperature ,actual temperature and wind speed have more significant effect on count of rented bikes.

# %% [markdown]
# ## Model Building

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)

corr_matrix = df2.corr()
print(corr_matrix["cnt"].sort_values(ascending=False))
# Out:
# cnt           1.000000
# registered    0.945411
# casual        0.672123
# atemp         0.630685
# instant       0.629896
# temp          0.627044
# yr            0.569728
# season        0.404584
# mnth          0.278191
# weekday       0.036183
# workingday   -0.027640
# holiday      -0.068764
# hum          -0.098543
# windspeed    -0.235132
# weathersit   -0.295929
# Name: cnt, dtype: float64

# %%
X = df2[['weathersit','windspeed','season','yr','temp','mnth']]
Y = df2['cnt']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
model.coef_
# Out:
# array([-713.71128459,  -35.29599864,  456.71462347, 2012.1208888 ,
#         124.72959694,  -40.02794153])

# %%
model.intercept_
# Out:
# 1532.1806636415067

# %%
metrics.mean_squared_error(Y_test, y_pred)
# Out:
# 794741.113041722

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred)
# Out:
# 0.8204890336841945

# %%
model.score(X_test,Y_test)
# Out:
# 0.8204890336841945

# %%
# plt.scatter(df['cnt'],df['temp'])
# plt.plot(df['cnt'],df['temp'],color='red')
