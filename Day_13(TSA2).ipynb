# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,PolynomialFeatures,StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
# %matplotlib inline

# %%
# Example 1:
df = pd.read_csv('df_vacation.csv',parse_dates=['Month'],index_col=0)

# %%
df.head()
# Out:
#             Num_Search_Vacation
# Month
# 2004-01-01                   94
# 2004-02-01                   89
# 2004-03-01                   86
# 2004-04-01                   79
# 2004-05-01                   89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 190 entries, 2004-01-01 to 2019-10-01
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Num_Search_Vacation  190 non-null    int64
# dtypes: int64(1)
# memory usage: 3.0 KB

# %%
# Plot the time series graph
df.plot(color='red',grid=True,figsize=(40,10))
# Out:
# <Axes: xlabel='Month'>

# %%
# Example 2:
df = pd.read_csv('df_furniture.csv',parse_dates=['Month'],index_col=0)

# %%
# Plot the time series graph
df.plot(color='red',grid=True,figsize=(40,10))
# Out:
# <Axes: xlabel='Month'>

# %%
# Example 3:
df = pd.read_csv('df_bankofamerica.csv',parse_dates=['Date'],index_col=0)

# %%
# Plot the time series graph
df.plot(color='red',grid=True,figsize=(40,10))
# Out:
# <Axes: xlabel='Date'>

# %%
# Example 4:
df = pd.read_csv('df_jpmorgan.csv',parse_dates=['Date'],index_col=0)

# %%
# Plot the time series graph
df.plot(color='red',grid=True,figsize=(40,10))
# Out:
# <Axes: xlabel='Date'>

# %%
# Example 5:
df = pd.read_csv('df_temp.csv',parse_dates=['Date'],index_col=0)

# %%
# Plot the time series graph
df.plot(color='red',grid=True,figsize=(40,10))
# Out:
# <Axes: xlabel='Date'>
